# %% [markdown]
# # Data Cleaning and Preprocessing
# ## Essential skills for real-world data analysis

# %% [markdown]
# ## 1. Import Libraries and Load Sample Data

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Create a sample dataset with common issues
data = {
    'ID': [1, 2, 3, 4, 5, 6, 7, 8],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Henry'],
    'Age': [25, 30, np.nan, 35, 28, 32, np.nan, 29],
    'Salary': [50000, 60000, 55000, np.nan, 52000, 61000, 58000, 59000],
    'Department': ['Sales', 'IT', 'Sales', 'IT', 'HR', 'IT', 'HR', 'Sales']
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    ID     Name   Age   Salary Department
# 0   1    Alice  25.0  50000.0      Sales
# 1   2      Bob  30.0  60000.0         IT
# 2   3  Charlie   NaN  55000.0      Sales
# 3   4    David  35.0      NaN         IT
# 4   5      Eve  28.0  52000.0         HR
# 5   6    Frank  32.0  61000.0         IT
# 6   7    Grace   NaN  58000.0         HR
# 7   8    Henry  29.0  59000.0      Sales

# %% [markdown]
# ## 2. Data Inspection

# %%
# Basic info
print("DataFrame Info:")
print(df.info())

print("\nDataFrame Description:")
print(df.describe())

print("\nData Types:")
print(df.dtypes)

print("\nMemory Usage:")
print(df.memory_usage(deep=True))
# Out:
# DataFrame Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          8 non-null      int64
#  1   Name        8 non-null      str
#  2   Age         6 non-null      float64
#  3   Salary      7 non-null      float64
#  4   Department  8 non-null      str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 452.0 bytes
# None
#
# DataFrame Description:
#             ID        Age        Salary
# count  8.00000   6.000000      7.000000
# mean   4.50000  29.833333  56428.571429
# std    2.44949   3.430258   4197.504928
# min    1.00000  25.000000  50000.000000
# 25%    2.75000  28.250000  53500.000000
# 50%    4.50000  29.500000  58000.000000
# 75%    6.25000  31.500000  59500.000000
# max    8.00000  35.000000  61000.000000
#
# Data Types:
# ID              int64
# Name              str
# Age           float64
# Salary        float64
# Department        str
# dtype: object
#
# Memory Usage:
# Index         132
# ID             64
# Name          430
# Age            64
# Salary         64
# Department    417
# dtype: int64

# %%
# Missing values detection
print("Missing values:")
print(df.isnull().sum())

print("\nMissing value percentage:")
print((df.isnull().sum() / len(df) * 100).round(2))
# Out:
# Missing values:
# ID            0
# Name          0
# Age           2
# Salary        1
# Department    0
# dtype: int64
#
# Missing value percentage:
# ID             0.0
# Name           0.0
# Age           25.0
# Salary        12.5
# Department     0.0
# dtype: float64

# %% [markdown]
# ## 3. Handling Missing Values

# %%
# Create a copy for demonstration
df_copy = df.copy()

# Drop rows with any missing values
df_dropped = df_copy.dropna()
print("After dropping NaN rows:")
print(df_dropped)
print(f"Rows reduced from {len(df_copy)} to {len(df_dropped)}")
# Out:
# After dropping NaN rows:
#    ID   Name   Age   Salary Department
# 0   1  Alice  25.0  50000.0      Sales
# 1   2    Bob  30.0  60000.0         IT
# 4   5    Eve  28.0  52000.0         HR
# 5   6  Frank  32.0  61000.0         IT
# 7   8  Henry  29.0  59000.0      Sales
# Rows reduced from 8 to 5

# %%
# Fill missing values with mean
df_filled_mean = df.copy()
df_filled_mean['Age'] = df_filled_mean['Age'].fillna(df_filled_mean['Age'].mean())
df_filled_mean['Salary'] = df_filled_mean['Salary'].fillna(df_filled_mean['Salary'].mean())

print("After filling with mean:")
print(df_filled_mean)
print(f"\nMissing values: {df_filled_mean.isnull().sum().sum()}")
# Out:
# After filling with mean:
#    ID     Name        Age        Salary Department
# 0   1    Alice  25.000000  50000.000000      Sales
# 1   2      Bob  30.000000  60000.000000         IT
# 2   3  Charlie  29.833333  55000.000000      Sales
# 3   4    David  35.000000  56428.571429         IT
# 4   5      Eve  28.000000  52000.000000         HR
# 5   6    Frank  32.000000  61000.000000         IT
# 6   7    Grace  29.833333  58000.000000         HR
# 7   8    Henry  29.000000  59000.000000      Sales
#
# Missing values: 0

# %%
# Forward fill and backward fill
df_ffill = df.copy()

df_ffill['Age'] = df_ffill['Age'].ffill()
df_ffill['Salary'] = df_ffill['Salary'].bfill()

print("After forward/backward fill:")
print(df_ffill)
# Out:
# After forward/backward fill:
#    ID     Name   Age   Salary Department
# 0   1    Alice  25.0  50000.0      Sales
# 1   2      Bob  30.0  60000.0         IT
# 2   3  Charlie  30.0  55000.0      Sales
# 3   4    David  35.0  52000.0         IT
# 4   5      Eve  28.0  52000.0         HR
# 5   6    Frank  32.0  61000.0         IT
# 6   7    Grace  32.0  58000.0         HR
# 7   8    Henry  29.0  59000.0      Sales

# %% [markdown]
# ## 4. Handling Duplicates

# %%
# Create data with duplicates
df_dup = pd.DataFrame({
    'ID': [1, 2, 2, 3, 3, 3],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'Charlie', 'Charlie'],
    'Value': [100, 200, 200, 300, 300, 300]
})

print("Data with duplicates:")
print(df_dup)

print("\nDuplicate rows:")
print(df_dup.duplicated())

print("\nAfter removing duplicates:")
df_no_dup = df_dup.drop_duplicates()
print(df_no_dup)
# Out:
# Data with duplicates:
#    ID     Name  Value
# 0   1    Alice    100
# 1   2      Bob    200
# 2   2      Bob    200
# 3   3  Charlie    300
# 4   3  Charlie    300
# 5   3  Charlie    300
#
# Duplicate rows:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool
#
# After removing duplicates:
#    ID     Name  Value
# 0   1    Alice    100
# 1   2      Bob    200
# 3   3  Charlie    300

# %% [markdown]
# ## 5. Type Conversion

# %%
# Type conversion examples
df_types = pd.DataFrame({
    'Age': ['25', '30', '35'],
    'Salary': ['50000', '60000', '55000'],
    'Active': ['Yes', 'No', 'Yes']
})

print("Original dtypes:")
print(df_types.dtypes)
print(df_types)

# Convert to numeric
df_types['Age'] = df_types['Age'].astype('int')
df_types['Salary'] = pd.to_numeric(df_types['Salary'])

print("\nAfter conversion:")
print(df_types.dtypes)
print(df_types)
# Out:
# Original dtypes:
# Age       str
# Salary    str
# Active    str
# dtype: object
#   Age Salary Active
# 0  25  50000    Yes
# 1  30  60000     No
# 2  35  55000    Yes
#
# After conversion:
# Age       int64
# Salary    int64
# Active      str
# dtype: object
#    Age  Salary Active
# 0   25   50000    Yes
# 1   30   60000     No
# 2   35   55000    Yes

# %% [markdown]
# ## 6. Scaling and Normalization

# %%
# Create sample numeric data
data_scale = pd.DataFrame({
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 55000],
    'Experience': [2, 5, 7]
})

print("Original data:")
print(data_scale)

# Standard scaling (z-score normalization)
scaler = StandardScaler()
scaled_std = pd.DataFrame(
    scaler.fit_transform(data_scale),
    columns=data_scale.columns
)

print("\nStandardized (Z-score):")
print(scaled_std)
print(f"Mean: {scaled_std.mean().values}")
print(f"Std: {scaled_std.std().values}")
# Out:
# Original data:
#    Age  Salary  Experience
# 0   25   50000           2
# 1   30   60000           5
# 2   35   55000           7
#
# Standardized (Z-score):
#         Age    Salary  Experience
# 0 -1.224745 -1.224745   -1.297771
# 1  0.000000  1.224745    0.162221
# 2  1.224745  0.000000    1.135550
# Mean: [ 0.00000000e+00  0.00000000e+00 -1.48029737e-16]
# Std: [1.22474487 1.22474487 1.22474487]

# %%
# Min-Max scaling (0-1 normalization)
scaler_mm = MinMaxScaler()
scaled_mm = pd.DataFrame(
    scaler_mm.fit_transform(data_scale),
    columns=data_scale.columns
)

print("Min-Max Scaled (0-1):")
print(scaled_mm)
print(f"Min: {scaled_mm.min().values}")
print(f"Max: {scaled_mm.max().values}")
# Out:
# Min-Max Scaled (0-1):
#    Age  Salary  Experience
# 0  0.0     0.0         0.0
# 1  0.5     1.0         0.6
# 2  1.0     0.5         1.0
# Min: [0. 0. 0.]
# Max: [1. 1. 1.]

# %% [markdown]
# ## 7. Encoding Categorical Variables

# %%
# Create categorical data
df_cat = pd.DataFrame({
    'Department': ['Sales', 'IT', 'HR', 'Sales', 'IT'],
    'Level': ['Junior', 'Senior', 'Junior', 'Senior', 'Junior']
})

print("Original data:")
print(df_cat)

# One-hot encoding
df_onehot = pd.get_dummies(df_cat, columns=['Department', 'Level'])
print("\nOne-hot encoded:")
print(df_onehot)
# Out:
# Original data:
#   Department   Level
# 0      Sales  Junior
# 1         IT  Senior
# 2         HR  Junior
# 3      Sales  Senior
# 4         IT  Junior
#
# One-hot encoded:
#    Department_HR  Department_IT  Department_Sales  Level_Junior  Level_Senior
# 0          False          False              True          True         False
# 1          False           True             False         False          True
# 2           True          False             False          True         False
# 3          False          False              True         False          True
# 4          False           True             False          True         False

# %%
# Ordinal encoding (mapping)
df_ordinal = df_cat.copy()
level_map = {'Junior': 1, 'Senior': 2}
dept_map = {'Sales': 1, 'IT': 2, 'HR': 3}

df_ordinal['Level'] = df_ordinal['Level'].map(level_map)
df_ordinal['Department'] = df_ordinal['Department'].map(dept_map)

print("Ordinal encoded:")
print(df_ordinal)
# Out:
# Ordinal encoded:
#    Department  Level
# 0           1      1
# 1           2      2
# 2           3      1
# 3           1      2
# 4           2      1

# %% [markdown]
# ## 8. Date/Time Parsing and Feature Extraction

# %%
# Create date data
df_dates = pd.DataFrame({
    'Date': ['2023-01-15', '2023-02-20', '2023-03-10'],
    'Amount': [100, 200, 150]
})

print("Original data:")
print(df_dates)
print(df_dates.dtypes)

# Parse dates
df_dates['Date'] = pd.to_datetime(df_dates['Date'])

# Extract date features
df_dates['Year'] = df_dates['Date'].dt.year
df_dates['Month'] = df_dates['Date'].dt.month
df_dates['Day'] = df_dates['Date'].dt.day
df_dates['DayOfWeek'] = df_dates['Date'].dt.dayofweek

print("\nAfter parsing and feature extraction:")
print(df_dates)
# Out:
# Original data:
#          Date  Amount
# 0  2023-01-15     100
# 1  2023-02-20     200
# 2  2023-03-10     150
# Date        str
# Amount    int64
# dtype: object
#
# After parsing and feature extraction:
#         Date  Amount  Year  Month  Day  DayOfWeek
# 0 2023-01-15     100  2023      1   15          6
# 1 2023-02-20     200  2023      2   20          0
# 2 2023-03-10     150  2023      3   10          4

# %% [markdown]
# ## 9. Save Cleaned Data

# %%
# Example: Save cleaned data
cleaned_df = df_filled_mean[['ID', 'Name', 'Age', 'Salary', 'Department']]

# Save to CSV
# cleaned_df.to_csv('../output/cleaned_data.csv', index=False)
print("Cleaned data ready to save:")
print(cleaned_df)
print(f"\nShape: {cleaned_df.shape}")
print(f"Missing values: {cleaned_df.isnull().sum().sum()}")
